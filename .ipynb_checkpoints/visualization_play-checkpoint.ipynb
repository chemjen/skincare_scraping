# %%
df = pd.read_csv('sephora_clean.csv')

# %%
df.sample(10)
# Out:
#                                                  name                brand  \
# 4874  Good in Bed™ Passionfruit Softening Night Cream             GLAMGLOW
# 159                  L’Atelier de Givenchy Cuir Blanc             GIVENCHY
# 3803            The Chaser High-Shine Finishing Cream               DRYBAR
# 4088                           Radiant Ruby Lip Crème        AETHER BEAUTY
# 294                          Full Lash and Brow Serum             SHISEIDO
# 1310                         SEA Lip Facial Lip Scrub                TARTE
# 1609           FAB Pharma Arnica Relief & Rescue Mask     FIRST AID BEAUTY
# 4385                                    Silver Powder        MARIO BADESCU
# 1323             Superberry Hydrate + Glow Dream Mask  YOUTH TO THE PEOPLE
# 4479    Milk Anti-Frizz Leave-In Nourishing Treatment              REVERIE
#
#          family                      genus                 species  price  \
# ...
